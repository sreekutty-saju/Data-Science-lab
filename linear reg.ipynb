# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
df= pd.read_csv('w.csv')
df.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  ...  Unnamed: 19  RISK_MM  RainTomorrow
# 0      8.0     24.3       0.0  ...          NaN      3.6           Yes
# 1     14.0     26.9       3.6  ...          NaN      3.6           Yes
# 2     13.7     23.4       3.6  ...          NaN     39.8           Yes
# 3     13.3     15.5      39.8  ...          NaN      2.8           Yes
# 4      7.6     16.1       2.8  ...          NaN      0.0            No
#
# [5 rows x 22 columns]

# %%
df.plot(x='MinTemp', y='MaxTemp' , style='o')
plt.title('min vs max')
plt.xlabel('mintemp')
plt.ylabel('maxtemp')
plt.show()

# %%
X= df['MinTemp'].values.reshape(-1,1)
y= df['MaxTemp'].values.reshape(-1,1)
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2, random_state=0)

# %%
model =LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('Intercept is :',model.intercept_)

print('Coefficient is :' ,model.coef_)
y_pred= model.predict(X_test)
maxtemp=model.predict([[12]])
print(maxtemp)
# Out:
# Intercept is : [14.56202411]
# Coefficient is : [[0.81953755]]
# [[24.39647471]]

# %%
plt.scatter(X_test,y_test,color='green')
plt.plot(X_test,y_pred,color='red',linewidth=2)
plt.show()
print('Mean abolute error is:', metrics.mean_absolute_error(y_test,y_pred))
print('Mean squared error is:', metrics.mean_squared_error(y_test,y_pred))
print('Root mean squared error is:', np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# Mean abolute error is: 3.5094353112899594
# Mean squared error is: 17.011877668640622
# Root mean squared error is: 4.124545753006096
