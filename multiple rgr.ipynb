# %%
import pandas
from sklearn import linear_model
from sklearn.model_selection import train_test_split
df = pandas.read_csv("cars.csv")
import matplotlib.pyplot as plt
from sklearn import metrics


X = df[['Weight', 'Volume']]
y = df['CO2']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2, random_state=0)

regr = linear_model.LinearRegression()
regr.fit(X, y)

print('Intercept is :',regr.intercept_)
print('Coefficient is :' ,regr.coef_)
y_pred= regr.predict(X_test)
#print('predicted values:',y_pred)
print('Mean squared error is:', metrics.mean_squared_error(y_test,y_pred))
CO= regr.predict([[2000,1400]])
print('co2 for weight=2000 and volume=1400 is ',CO)
# Out:
# Intercept is : 79.69471929115937
# Coefficient is : [0.00755095 0.00780526]
# Mean squared error is: 40.86282453680146
# co2 for weight=2000 and volume=1400 is  [105.72397437]
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:446: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
