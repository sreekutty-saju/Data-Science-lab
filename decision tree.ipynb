# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_iris
from sklearn import tree
a=load_iris()
x=a.data
y=a.target
x_train,x_test,y_train,y_test=(train_test_split(x,y,test_size=1/3,random_state=0))
from sklearn.tree import DecisionTreeClassifier
clfr=DecisionTreeClassifier()
clfr.fit(x_train,y_train)
train=clfr.predict(x_train)
test=clfr.predict(x_test)
print("Train Accuracy:",accuracy_score(y_true=y_train,y_pred=train))
print("Test Accuracy:",accuracy_score(y_true=y_test,y_pred=test))
tree.plot_tree(clfr)
# Out:
# Train Accuracy: 1.0
# Test Accuracy: 0.96
# [Text(148.8, 199.32, 'X[3] <= 0.75\ngini = 0.666\nsamples = 100\nvalue = [34, 31, 35]'),
#  Text(111.60000000000001, 163.07999999999998, 'gini = 0.0\nsamples = 34\nvalue = [34, 0, 0]'),
#  Text(186.0, 163.07999999999998, 'X[3] <= 1.75\ngini = 0.498\nsamples = 66\nvalue = [0, 31, 35]'),
#  Text(111.60000000000001, 126.83999999999999, 'X[2] <= 5.05\ngini = 0.165\nsamples = 33\nvalue = [0, 30, 3]'),
#  Text(74.4, 90.6, 'X[3] <= 1.65\ngini = 0.062\nsamples = 31\nvalue = [0, 30, 1]'),
#  Text(37.2, 54.359999999999985, 'gini = 0.0\nsamples = 29\nvalue = [0, 29, 0]'),
#  Text(111.60000000000001, 54.359999999999985, 'X[2] <= 4.75\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(74.4, 18.119999999999976, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(148.8, 18.119999999999976, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(148.8, 90.6, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(260.40000000000003, 126.83999999999999, 'X[2] <= 4.85\ngini = 0.059\nsamples = 33\nvalue = [0, 1, 32]'),
#  Text(223.20000000000002, 90.6, 'X[0] <= 5.95\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(186.0, 54.359999999999985, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(260.40000000000003, 54.359999999999985, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(297.6, 90.6, 'gini = 0.0\nsamples = 31\nvalue = [0, 0, 31]')]
